# %% [markdown]
# a) Cargue los datos dos dataset de entrenamiento y de pruebas ¿Cuántos datos hay en cada conjunto?

# %%
import scipy.io as sio
mat_test=sio.loadmat('AgeGenderClassification/eventest')
mat_train=sio.loadmat('AgeGenderClassification/eventrain')
data_train= mat_train["trcoll"][0][0]
data_test= mat_test["tecoll"][0][0]
print(data_train[1].shape)
print(data_test[1].shape)
# Out:
# (3500, 1)
# (1050, 1)

# %% [markdown]
# Se cuentan con 3500 datos de entrenamiento y 1050 de validación.

# %% [markdown]
# b) Eliga cuál representación utilizará para trabajar los datos y entregárselos como input al modelo neuronal denso. Además extraiga las etiquetas del problema. Describa los datos utilziados.

# %%
for i in range(6):
    print(data_train[i].shape)
# Out:
# (3500, 14)
# (3500, 1)
# (3500, 1)
# (3500, 37)
# (3500, 600)
# (3500, 2989)

# %% [markdown]
# [0]: Features: posicion, tamaño relativo, angulo, etc <br>
# [1]: Edad <br>
# [2]: Sexo <br>
# [3]: fisherface space  (representación de baja dimensionalidad similar a eigenfaces, donde estos serian los eigenvalues) <br>
# [5]: imagen original (fila de 2989 (61x49))<br>

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.rcParams["figure.figsize"]=[18,5]
for i in range(20):
    plt.subplot(2,10,i+1);
    plt.title(data_train[1][i])
    plt.imshow(np.reshape(data_train[5][i],[49,61]).T);
# Out:
# /home/gabrielrudloff/anaconda3/envs/redesneuronales/lib/python3.6/site-packages/matplotlib/text.py:1190: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
plt.hist(data_train[1]);

# %% [markdown]
# Se elige utilizar como entrada las imagenes originales (normalizadas), ya que esto da más generalidad a la solución. Con esta solución seria necesario solo detectar el ROI donde se encuentra una cara, y no hacer más preprocesamiento. Además se elige tomar el problema como uno multiclase, por lo que se convertira las etiquetas de salida en un "one hot vector", es decir un vector de ceros, con un uno en la posición de la etiqueta a la que corresponde.

# %% [markdown]
# c) Defina y entrene una modelo de red neuronal feed forward para la inferencia de la edad de la persona a través de la representación escogida. Intente llegar a un mse menor a 100 en el conjunto de pruebas. Recuerde que NO puede seleccionar modelos a través del conjunto de pruebas. Visualice sus resultados si estima conveniente.

# %%
def map_clases(arg):
    switcher = {
        1:0,
        5:1,
        10:2,
        16:3,
        28:4,
        51:5,
        75:6
    }
    return switcher.get(arg,-1)

# %%
import keras
import pandas as pd
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD,Adam
from sklearn.preprocessing import StandardScaler
from keras.layers import Dropout
from keras.metrics import categorical_accuracy
x_train=data_train[5];
x_val=data_test[5];

scaler = StandardScaler().fit(x_train)
X_train_scaled = pd.DataFrame(scaler.transform(x_train))
X_val_scaled = pd.DataFrame(scaler.transform(x_val))

#mapeo
y_train_map=[map_clases(int(data_train[1][i])) for i in range(len(data_train[1]))];
y_val_map=[map_clases(int(data_test[1][i])) for i in range(len(data_test[1]))];

y_train = keras.utils.to_categorical(y_train_map,num_classes=7);
y_val = keras.utils.to_categorical(y_val_map,num_classes=7);

model = Sequential()
model.add(Dense(512, input_dim=X_train_scaled.shape[1], kernel_initializer='uniform',activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(256, kernel_initializer='uniform',activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(256, kernel_initializer='uniform',activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(128, kernel_initializer='uniform',activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(7, kernel_initializer='uniform',activation="softmax"))
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=[categorical_accuracy])
history = model.fit(X_train_scaled, y_train,batch_size=32, epochs=150, verbose=1, validation_data=(X_val_scaled, y_val))
# Out:
# /home/gabrielrudloff/anaconda3/envs/redesneuronales/lib/python3.6/site-packages/sklearn/utils/validation.py:590: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/gabrielrudloff/anaconda3/envs/redesneuronales/lib/python3.6/site-packages/sklearn/utils/validation.py:590: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/gabrielrudloff/anaconda3/envs/redesneuronales/lib/python3.6/site-packages/sklearn/utils/validation.py:590: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# Train on 3500 samples, validate on 1050 samples
# Epoch 1/150
# 3500/3500 [==============================] - 1s 383us/step - loss: 1.9083 - categorical_accuracy: 0.2089 - val_loss: 1.7886 - val_categorical_accuracy: 0.2924
# Epoch 2/150
# 3500/3500 [==============================] - 1s 203us/step - loss: 1.7452 - categorical_accuracy: 0.2886 - val_loss: 1.6758 - val_categorical_accuracy: 0.2924
# Epoch 3/150
# 3500/3500 [==============================] - 1s 202us/step - loss: 1.6396 - categorical_accuracy: 0.3220 - val_loss: 1.5990 - val_categorical_accuracy: 0.3381
# Epoch 4/150
# 3500/3500 [==============================] - 1s 200us/step - loss: 1.5899 - categorical_accuracy: 0.3560 - val_loss: 1.5975 - val_categorical_accuracy: 0.3581
# Epoch 5/150
# 3500/3500 [==============================] - 1s 201us/step - loss: 1.5629 - categorical_accuracy: 0.3694 - val_loss: 1.5950 - val_categorical_accuracy: 0.3352
# Epoch 6/150
# 3500/3500 [==============================] - 1s 202us/step - loss: 1.5359 - categorical_accuracy: 0.3726 - val_loss: 1.5854 - val_categorical_accuracy: 0.3495
# Epoch 7/150
# 3500/3500 [==============================] - 1s 200us/step - loss: 1.4991 - categorical_accuracy: 0.4003 - val_loss: 1.5707 - val_categorical_accuracy: 0.3543
# Epoch 8/150
# 3500/3500 [==============================] - 1s 198us/step - loss: 1.5150 - categorical_accuracy: 0.3820 - val_loss: 1.5498 - val_categorical_accuracy: 0.3610
# Epoch 9/150
# 3500/3500 [==============================] - 1s 204us/step - loss: 1.4806 - categorical_accuracy: 0.3923 - val_loss: 1.5116 - val_categorical_accuracy: 0.3876
# Epoch 10/150
# 3500/3500 [==============================] - 1s 203us/step - loss: 1.4695 - categorical_accuracy: 0.4026 - val_loss: 1.5190 - val_categorical_accuracy: 0.3590
# Epoch 11/150
# 3500/3500 [==============================] - 1s 199us/step - loss: 1.4294 - categorical_accuracy: 0.4220 - val_loss: 1.5343 - val_categorical_accuracy: 0.3924
# Epoch 12/150
# 3500/3500 [==============================] - 1s 195us/step - loss: 1.4167 - categorical_accuracy: 0.4271 - val_loss: 1.5493 - val_categorical_accuracy: 0.3857
# Epoch 13/150
# 3500/3500 [==============================] - 1s 200us/step - loss: 1.3975 - categorical_accuracy: 0.4326 - val_loss: 1.5554 - val_categorical_accuracy: 0.3676
# Epoch 14/150
# 3500/3500 [==============================] - 1s 199us/step - loss: 1.4188 - categorical_accuracy: 0.4426 - val_loss: 1.5126 - val_categorical_accuracy: 0.3962
# Epoch 15/150
# 3500/3500 [==============================] - 1s 204us/step - loss: 1.3828 - categorical_accuracy: 0.4340 - val_loss: 1.4982 - val_categorical_accuracy: 0.3762
# Epoch 16/150
# 3500/3500 [==============================] - 1s 203us/step - loss: 1.3496 - categorical_accuracy: 0.4629 - val_loss: 1.4635 - val_categorical_accuracy: 0.4019
# Epoch 17/150
# 3500/3500 [==============================] - 1s 200us/step - loss: 1.3342 - categorical_accuracy: 0.4540 - val_loss: 1.4865 - val_categorical_accuracy: 0.4010
# Epoch 18/150
# 3500/3500 [==============================] - 1s 220us/step - loss: 1.3377 - categorical_accuracy: 0.4520 - val_loss: 1.4462 - val_categorical_accuracy: 0.3867
# Epoch 19/150
# 3500/3500 [==============================] - 1s 220us/step - loss: 1.3215 - categorical_accuracy: 0.4643 - val_loss: 1.5078 - val_categorical_accuracy: 0.3990
# Epoch 20/150
# 3500/3500 [==============================] - 1s 201us/step - loss: 1.3361 - categorical_accuracy: 0.4571 - val_loss: 1.4669 - val_categorical_accuracy: 0.4105
# Epoch 21/150
# 3500/3500 [==============================] - 1s 199us/step - loss: 1.3314 - categorical_accuracy: 0.4634 - val_loss: 1.4974 - val_categorical_accuracy: 0.3857
# Epoch 22/150
# 3500/3500 [==============================] - 1s 212us/step - loss: 1.3358 - categorical_accuracy: 0.4614 - val_loss: 1.4604 - val_categorical_accuracy: 0.3981
# Epoch 23/150
# 3500/3500 [==============================] - 1s 224us/step - loss: 1.3042 - categorical_accuracy: 0.4711 - val_loss: 1.4693 - val_categorical_accuracy: 0.4067
# Epoch 24/150
# 3500/3500 [==============================] - 1s 213us/step - loss: 1.2980 - categorical_accuracy: 0.4786 - val_loss: 1.5279 - val_categorical_accuracy: 0.3762
# Epoch 25/150
# 3500/3500 [==============================] - 1s 200us/step - loss: 1.2984 - categorical_accuracy: 0.4620 - val_loss: 1.5091 - val_categorical_accuracy: 0.3943
# Epoch 26/150
# 3500/3500 [==============================] - 1s 208us/step - loss: 1.2853 - categorical_accuracy: 0.4783 - val_loss: 1.5146 - val_categorical_accuracy: 0.3943
# Epoch 27/150
# 3500/3500 [==============================] - 1s 199us/step - loss: 1.2704 - categorical_accuracy: 0.4854 - val_loss: 1.5365 - val_categorical_accuracy: 0.3619
# Epoch 28/150
# 3500/3500 [==============================] - 1s 203us/step - loss: 1.2996 - categorical_accuracy: 0.4703 - val_loss: 1.5570 - val_categorical_accuracy: 0.3857
# Epoch 29/150
# 3500/3500 [==============================] - 1s 200us/step - loss: 1.2464 - categorical_accuracy: 0.4917 - val_loss: 1.4789 - val_categorical_accuracy: 0.4010
# Epoch 30/150
# 3500/3500 [==============================] - 1s 225us/step - loss: 1.2366 - categorical_accuracy: 0.4820 - val_loss: 1.4992 - val_categorical_accuracy: 0.4200
# Epoch 31/150
# 3500/3500 [==============================] - 1s 218us/step - loss: 1.2677 - categorical_accuracy: 0.4874 - val_loss: 1.5061 - val_categorical_accuracy: 0.3848
# Epoch 32/150
# 3500/3500 [==============================] - 1s 202us/step - loss: 1.2501 - categorical_accuracy: 0.4906 - val_loss: 1.4838 - val_categorical_accuracy: 0.4105
# Epoch 33/150
# 3500/3500 [==============================] - 1s 212us/step - loss: 1.2091 - categorical_accuracy: 0.5074 - val_loss: 1.6054 - val_categorical_accuracy: 0.3857
# Epoch 34/150
# 3500/3500 [==============================] - 1s 199us/step - loss: 1.2620 - categorical_accuracy: 0.5063 - val_loss: 1.5006 - val_categorical_accuracy: 0.4238
# Epoch 35/150
# 3500/3500 [==============================] - 1s 203us/step - loss: 1.2002 - categorical_accuracy: 0.5120 - val_loss: 1.4979 - val_categorical_accuracy: 0.4162
# Epoch 36/150
# 3500/3500 [==============================] - 1s 198us/step - loss: 1.2061 - categorical_accuracy: 0.5077 - val_loss: 1.4782 - val_categorical_accuracy: 0.3971
# Epoch 37/150
# 3500/3500 [==============================] - 1s 207us/step - loss: 1.1903 - categorical_accuracy: 0.5157 - val_loss: 1.4785 - val_categorical_accuracy: 0.4010
# Epoch 38/150
# 3500/3500 [==============================] - 1s 208us/step - loss: 1.1881 - categorical_accuracy: 0.5171 - val_loss: 1.4944 - val_categorical_accuracy: 0.4038
# Epoch 39/150
# 3500/3500 [==============================] - 1s 201us/step - loss: 1.1798 - categorical_accuracy: 0.5171 - val_loss: 1.4990 - val_categorical_accuracy: 0.3952
# Epoch 40/150
# 3500/3500 [==============================] - 1s 201us/step - loss: 1.1679 - categorical_accuracy: 0.5249 - val_loss: 1.5056 - val_categorical_accuracy: 0.4095
# Epoch 41/150
# 3500/3500 [==============================] - 1s 223us/step - loss: 1.2120 - categorical_accuracy: 0.5154 - val_loss: 1.5030 - val_categorical_accuracy: 0.3886
# Epoch 42/150
# 3500/3500 [==============================] - 1s 221us/step - loss: 1.1831 - categorical_accuracy: 0.5214 - val_loss: 1.4557 - val_categorical_accuracy: 0.4095
# Epoch 43/150
# 3500/3500 [==============================] - 1s 210us/step - loss: 1.1695 - categorical_accuracy: 0.5257 - val_loss: 1.4739 - val_categorical_accuracy: 0.4238
# Epoch 44/150
# 3500/3500 [==============================] - 1s 211us/step - loss: 1.1778 - categorical_accuracy: 0.5103 - val_loss: 1.5140 - val_categorical_accuracy: 0.3886
# Epoch 45/150
# 3500/3500 [==============================] - 1s 209us/step - loss: 1.1503 - categorical_accuracy: 0.5389 - val_loss: 1.4490 - val_categorical_accuracy: 0.4057
# Epoch 46/150
# 3500/3500 [==============================] - 1s 206us/step - loss: 1.1377 - categorical_accuracy: 0.5217 - val_loss: 1.5281 - val_categorical_accuracy: 0.4114
# Epoch 47/150
# 3500/3500 [==============================] - 1s 208us/step - loss: 1.1506 - categorical_accuracy: 0.5366 - val_loss: 1.4745 - val_categorical_accuracy: 0.4095
# Epoch 48/150
# 3500/3500 [==============================] - 1s 202us/step - loss: 1.1813 - categorical_accuracy: 0.5206 - val_loss: 1.4889 - val_categorical_accuracy: 0.3952
# Epoch 49/150
# 3500/3500 [==============================] - 1s 200us/step - loss: 1.1450 - categorical_accuracy: 0.5329 - val_loss: 1.4739 - val_categorical_accuracy: 0.4124
# Epoch 50/150
# 3500/3500 [==============================] - 1s 212us/step - loss: 1.1258 - categorical_accuracy: 0.5434 - val_loss: 1.4992 - val_categorical_accuracy: 0.4162
# Epoch 51/150
# 3500/3500 [==============================] - 1s 222us/step - loss: 1.1186 - categorical_accuracy: 0.5377 - val_loss: 1.4917 - val_categorical_accuracy: 0.3962
# Epoch 52/150
# 3500/3500 [==============================] - 1s 214us/step - loss: 1.1298 - categorical_accuracy: 0.5451 - val_loss: 1.5305 - val_categorical_accuracy: 0.4181
# Epoch 53/150
# 3500/3500 [==============================] - 1s 204us/step - loss: 1.1194 - categorical_accuracy: 0.5443 - val_loss: 1.4949 - val_categorical_accuracy: 0.4219
# Epoch 54/150
# 3500/3500 [==============================] - 1s 202us/step - loss: 1.1188 - categorical_accuracy: 0.5469 - val_loss: 1.4736 - val_categorical_accuracy: 0.4181
# Epoch 55/150
# 3500/3500 [==============================] - 1s 208us/step - loss: 1.1101 - categorical_accuracy: 0.5420 - val_loss: 1.4841 - val_categorical_accuracy: 0.4029
# Epoch 56/150
# 3500/3500 [==============================] - 1s 207us/step - loss: 1.1161 - categorical_accuracy: 0.5480 - val_loss: 1.4892 - val_categorical_accuracy: 0.4010
# Epoch 57/150
# 3500/3500 [==============================] - 1s 222us/step - loss: 1.0929 - categorical_accuracy: 0.5474 - val_loss: 1.5761 - val_categorical_accuracy: 0.4181
# Epoch 58/150
# 3500/3500 [==============================] - 1s 227us/step - loss: 1.1302 - categorical_accuracy: 0.5437 - val_loss: 1.5018 - val_categorical_accuracy: 0.3933
# Epoch 59/150
# 3500/3500 [==============================] - 1s 231us/step - loss: 1.1079 - categorical_accuracy: 0.5574 - val_loss: 1.5581 - val_categorical_accuracy: 0.4019
# Epoch 60/150
# 3500/3500 [==============================] - 1s 232us/step - loss: 1.0954 - categorical_accuracy: 0.5520 - val_loss: 1.4642 - val_categorical_accuracy: 0.4133
# Epoch 61/150
# 3500/3500 [==============================] - 1s 203us/step - loss: 1.1140 - categorical_accuracy: 0.5537 - val_loss: 1.4966 - val_categorical_accuracy: 0.4114
# Epoch 62/150
# 3500/3500 [==============================] - 1s 204us/step - loss: 1.0955 - categorical_accuracy: 0.5537 - val_loss: 1.5128 - val_categorical_accuracy: 0.4019
# Epoch 63/150
# 3500/3500 [==============================] - 1s 203us/step - loss: 1.0837 - categorical_accuracy: 0.5611 - val_loss: 1.5050 - val_categorical_accuracy: 0.4086
# Epoch 64/150
# 3500/3500 [==============================] - 1s 212us/step - loss: 1.0980 - categorical_accuracy: 0.5520 - val_loss: 1.5205 - val_categorical_accuracy: 0.4133
# Epoch 65/150
# 3500/3500 [==============================] - 1s 226us/step - loss: 1.0663 - categorical_accuracy: 0.5823 - val_loss: 1.5439 - val_categorical_accuracy: 0.4095
# Epoch 66/150
# 3500/3500 [==============================] - 1s 226us/step - loss: 1.1230 - categorical_accuracy: 0.5560 - val_loss: 1.5199 - val_categorical_accuracy: 0.4124
# Epoch 67/150
# 3500/3500 [==============================] - 1s 210us/step - loss: 1.0710 - categorical_accuracy: 0.5714 - val_loss: 1.5487 - val_categorical_accuracy: 0.3857
# Epoch 68/150
# 3500/3500 [==============================] - 1s 212us/step - loss: 1.0735 - categorical_accuracy: 0.5709 - val_loss: 1.5393 - val_categorical_accuracy: 0.4000
# Epoch 69/150
# 3500/3500 [==============================] - 1s 224us/step - loss: 1.0596 - categorical_accuracy: 0.5706 - val_loss: 1.5395 - val_categorical_accuracy: 0.4133
# Epoch 70/150
# 3500/3500 [==============================] - 1s 217us/step - loss: 1.0508 - categorical_accuracy: 0.5789 - val_loss: 1.5398 - val_categorical_accuracy: 0.4133
# Epoch 71/150
# 3500/3500 [==============================] - 1s 206us/step - loss: 1.0569 - categorical_accuracy: 0.5680 - val_loss: 1.5243 - val_categorical_accuracy: 0.4257
# Epoch 72/150
# 3500/3500 [==============================] - 1s 219us/step - loss: 1.0396 - categorical_accuracy: 0.5786 - val_loss: 1.5759 - val_categorical_accuracy: 0.4190
# Epoch 73/150
# 3500/3500 [==============================] - 1s 214us/step - loss: 1.0400 - categorical_accuracy: 0.5800 - val_loss: 1.6376 - val_categorical_accuracy: 0.4419
# Epoch 74/150
# 3500/3500 [==============================] - 1s 212us/step - loss: 1.0193 - categorical_accuracy: 0.5846 - val_loss: 1.5594 - val_categorical_accuracy: 0.4162
# Epoch 75/150
# 3500/3500 [==============================] - 1s 206us/step - loss: 1.0380 - categorical_accuracy: 0.5871 - val_loss: 1.5541 - val_categorical_accuracy: 0.4029
# Epoch 76/150
# 3500/3500 [==============================] - 1s 202us/step - loss: 1.0579 - categorical_accuracy: 0.5777 - val_loss: 1.5378 - val_categorical_accuracy: 0.3971
# Epoch 77/150
# 3500/3500 [==============================] - 1s 209us/step - loss: 1.0712 - categorical_accuracy: 0.5643 - val_loss: 1.5004 - val_categorical_accuracy: 0.4019
# Epoch 78/150
# 3500/3500 [==============================] - 1s 205us/step - loss: 1.0443 - categorical_accuracy: 0.5823 - val_loss: 1.5751 - val_categorical_accuracy: 0.4076
# Epoch 79/150
# 3500/3500 [==============================] - 1s 221us/step - loss: 1.0599 - categorical_accuracy: 0.5751 - val_loss: 1.6303 - val_categorical_accuracy: 0.3962
# Epoch 80/150
# 3500/3500 [==============================] - 1s 225us/step - loss: 0.9919 - categorical_accuracy: 0.5997 - val_loss: 1.5888 - val_categorical_accuracy: 0.4171
# Epoch 81/150
# 3500/3500 [==============================] - 1s 218us/step - loss: 1.0224 - categorical_accuracy: 0.5954 - val_loss: 1.5928 - val_categorical_accuracy: 0.3857
# Epoch 82/150
# 3500/3500 [==============================] - 1s 214us/step - loss: 1.0209 - categorical_accuracy: 0.5871 - val_loss: 1.5405 - val_categorical_accuracy: 0.4267
# Epoch 83/150
# 3500/3500 [==============================] - 1s 234us/step - loss: 0.9920 - categorical_accuracy: 0.6103 - val_loss: 1.6105 - val_categorical_accuracy: 0.4295
# Epoch 84/150
# 3500/3500 [==============================] - 1s 225us/step - loss: 1.0314 - categorical_accuracy: 0.5923 - val_loss: 1.6009 - val_categorical_accuracy: 0.4267
# Epoch 85/150
# 3500/3500 [==============================] - 1s 212us/step - loss:
150
# 3500/3500 [==============================] - 1s 210us/step - loss: 0.8870 - categorical_accuracy: 0.6586 - val_loss: 1.7521 - val_categorical_accuracy: 0.4343
# Epoch 150/150
# 3500/3500 [==============================] - 1s 206us/step - loss: 0.8852 - categorical_accuracy: 0.6629 - val_loss: 1.7550 - val_categorical_accuracy: 0.4143

# %%
plt.figure(num=None, figsize=(15, 10), dpi=80, facecolor='w', edgecolor='k')
plt.plot(history.history['loss'],label='train');
plt.plot(history.history['val_loss'],label='validation');
plt.ylabel('Loss');
plt.xlabel('Epoch')
plt.legend();
plt.grid()
plt.show()

# %%
match=np.sum(np.argmax(model.predict(X_val_scaled),axis=1)==np.argmax(y_val,axis=1));
print('aciertos='+str(match));
length=len(X_val_scaled);
print('largo='+str(length))
print('proporcion='+str(match/length))
# Out:
# aciertos=435
# largo=1050
# proporcion=0.4142857142857143

# %%
map_clases_inv=[1,5,10,16,28,51,75]
predict=[map_clases_inv[np.argmax(model.predict(X_val_scaled),axis=1)[i]] for i in range(len(X_val_scaled))];
plt.figure(num=None, figsize=(15, 10), dpi=80, facecolor='w', edgecolor='k')
plt.plot(predict,'go',color='blue');
plt.plot(data_test[1],'go',color='red');

# %%
mse=1/len(X_val_scaled)*sum([(predict[i]-data_test[1][i])**2 for i in range(len(X_val_scaled))]);
print('mse='+str(mse))
# Out:
# mse=[0.14190476]

# %% [markdown]
# Si bien se eligio utilizar solo la información de las imagenes a continuación se entrena el mismo modelo, pero ahora de entrada se entrega además el resto de información que se tiene en los primeros 5 conjuntos de datos, ya que de estos puede ser util para un modelo más optimo el saber el sexo, o el angulo, por dar algunos ejemplos.

# %%
import keras
import pandas as pd
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD,Adam
from sklearn.preprocessing import StandardScaler
from keras.layers import Dropout
from keras.metrics import categorical_accuracy
x_train=np.vstack((data_train[0].T,data_train[2].T,data_train[3].T,data_train[5].T)).T
x_val=np.vstack((data_test[0].T,data_test[2].T,data_test[3].T,data_test[5].T)).T
scaler = StandardScaler().fit(x_train)
X_train_scaled = pd.DataFrame(scaler.transform(x_train))
X_val_scaled = pd.DataFrame(scaler.transform(x_val))

#mapeo
y_train_map=[map_clases(int(data_train[1][i])) for i in range(len(data_train[1]))];
y_val_map=[map_clases(int(data_test[1][i])) for i in range(len(data_test[1]))];

y_train = keras.utils.to_categorical(y_train_map,num_classes=7);
y_val = keras.utils.to_categorical(y_val_map,num_classes=7);

model = Sequential()
model.add(Dense(512, input_dim=X_train_scaled.shape[1], kernel_initializer='uniform',activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(256, kernel_initializer='uniform',activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(256, kernel_initializer='uniform',activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(128, kernel_initializer='uniform',activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(7, kernel_initializer='uniform',activation="softmax"))
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=[categorical_accuracy])
history = model.fit(X_train_scaled, y_train,batch_size=32, epochs=150, verbose=1, validation_data=(X_val_scaled, y_val))
# Out:
# Train on 3500 samples, validate on 1050 samples
# Epoch 1/150
# 3500/3500 [==============================] - 1s 393us/step - loss: 1.9126 - categorical_accuracy: 0.2077 - val_loss: 1.7390 - val_categorical_accuracy: 0.2924
# Epoch 2/150
# 3500/3500 [==============================] - 1s 219us/step - loss: 1.7044 - categorical_accuracy: 0.3026 - val_loss: 1.6199 - val_categorical_accuracy: 0.3514
# Epoch 3/150
# 3500/3500 [==============================] - 1s 209us/step - loss:
150
# 3500/3500 [==============================] - 1s 209us/step - loss: 0.8075 - categorical_accuracy: 0.6971 - val_loss: 1.5548 - val_categorical_accuracy: 0.4476
# Epoch 141/150
# 3500/3500 [==============================] - 1s 235us/step - loss: 0.8286 - categorical_accuracy: 0.6860 - val_loss: 1.4876 - val_categorical_accuracy: 0.4695
# Epoch 142/150
# 3500/3500 [==============================] - 1s 218us/step - loss: 0.7680 - categorical_accuracy: 0.7051 - val_loss: 1.6156 - val_categorical_accuracy: 0.4829
# Epoch 143/150
# 3500/3500 [==============================] - 1s 201us/step - loss: 0.7987 - categorical_accuracy: 0.7037 - val_loss: 1.5907 - val_categorical_accuracy: 0.4771
# Epoch 144/150
# 3500/3500 [==============================] - 1s 207us/step - loss: 0.7689 - categorical_accuracy: 0.7151 - val_loss: 1.5403 - val_categorical_accuracy: 0.4705
# Epoch 145/150
# 3500/3500 [==============================] - 1s 209us/step - loss: 0.7775 - categorical_accuracy: 0.7080 - val_loss: 1.5410 - val_categorical_accuracy: 0.4524
# Epoch 146/150
# 3500/3500 [==============================] - 1s 226us/step - loss: 0.7551 - categorical_accuracy: 0.7117 - val_loss: 1.5242 - val_categorical_accuracy: 0.4838
# Epoch 147/150
# 3500/3500 [==============================] - 1s 216us/step - loss: 0.7721 - categorical_accuracy: 0.7054 - val_loss: 1.5958 - val_categorical_accuracy: 0.4876
# Epoch 148/150
# 3500/3500 [==============================] - 1s 211us/step - loss: 0.7489 - categorical_accuracy: 0.7140 - val_loss: 1.5621 - val_categorical_accuracy: 0.4838
# Epoch 149/150
# 3500/3500 [==============================] - 1s 211us/step - loss: 0.7683 - categorical_accuracy: 0.7137 - val_loss: 1.6705 - val_categorical_accuracy: 0.4686
# Epoch 150/150
# 3500/3500 [==============================] - 1s 212us/step - loss: 0.7937 - categorical_accuracy: 0.7129 - val_loss: 1.6099 - val_categorical_accuracy: 0.4762

# %%
plt.figure(num=None, figsize=(15, 10), dpi=80, facecolor='w', edgecolor='k')
plt.plot(history.history['loss'],label='train');
plt.plot(history.history['val_loss'],label='validation');
plt.ylabel('Loss');
plt.xlabel('Epoch')
plt.legend();
plt.grid()
plt.show()

# %%
match=np.sum(np.argmax(model.predict(X_val_scaled),axis=1)==np.argmax(y_val,axis=1));
print('aciertos='+str(match));
length=len(X_val_scaled);
print('largo='+str(length))
print('proporcion='+str(match/length))
# Out:
# aciertos=500
# largo=1050
# proporcion=0.47619047619047616

# %%
mse=1/len(X_val_scaled)*sum([(predict[i]-data_test[1][i])**2 for i in range(len(X_val_scaled))]);
print('mse='+str(mse))
# Out:
# mse=[0.14190476]

# %% [markdown]
# Podemos ver que si bien el desempeño mejoro un poco, no fue en gran cantidad. Solo se tiene un aumento de un ~5% en la exactitud de la predicción y el MSE tiene casi el mismo valor. A pesar de que en ningun caso se obtuvo un desempeño excepcional,
