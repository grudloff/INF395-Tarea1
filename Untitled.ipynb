# %%
lista = ['{0}','B1_','B2_','C1_','C2_','D1_','D2_','E1a_','E2a_','E1b_','E2b_','F1_','F2_','G1_','G2_','H1_','H2_']

codigo = "
########################################## MODELO DE LA RED\n
{0}model = Sequential()\n
{0}model.add(Dense(256, input_dim=X_train_scaled.shape[1], kernel_initializer='uniform',activation='sigmoid'))\n
{0}model.add(Dense(256, kernel_initializer='uniform',activation='sigmoid'))\n
{0}model.add(Dense(256,  kernel_initializer='uniform',activation='sigmoid'))\n
{0}model.add(Dense(256, kernel_initializer='uniform',activation='sigmoid'))\n
{0}model.add(Dense(256, kernel_initializer='uniform',activation='sigmoid'))\n
{0}model.add(Dense(1, kernel_initializer='uniform',activation='linear'))\n
{0}sgd = SGD(lr=0.01)\n
{0}model.compile(optimizer={0}sgd,loss='mean_squared_error')\n
\n
########################################## CALCULO DE LOS GRADIENTES\n
{0}loss = K.losses.mean_squared_error({0}model.output,y_train)\n
{0}listOfVariableTensors = {0}model.trainable_weights\n
{0}gradients = k.gradients({0}loss, {0}listOfVariableTensors)\n
\n
{0}sess = k.get_session()\n
\n
{0}evaluated_gradients = {0}sess.run({0}gradients,feed_dict={ {0}model.input:X_train_scaled.values})\n
{0}evaluated_gradients = [gradient/len(y_train) for gradient in {0}evaluated_gradients]\n
\n
########################################## OBTENCION DE PESOS \n
{0}weights0, {0}biases0 = {0}model.layers[0].get_weights()\n
{0}weights1, {0}biases1 = {0}model.layers[1].get_weights()\n
{0}weights2, {0}biases2 = {0}model.layers[2].get_weights()\n
{0}weights3, {0}biases3 = {0}model.layers[3].get_weights()\n
{0}weights4, {0}biases4 = {0}model.layers[4].get_weights()\n
{0}weights5, {0}biases5 = {0}model.layers[5].get_weights()\n
\n
########################################## OBTENCION DE GRADIENTES\n
{0}grafico0={0}evaluated_gradients[0]\n
{0}grafico1={0}evaluated_gradients[2]\n
{0}grafico2={0}evaluated_gradients[4]\n
{0}grafico3={0}evaluated_gradients[6]\n
{0}grafico4={0}evaluated_gradients[8]\n
{0}grafico5={0}evaluated_gradients[10]\n
\n
########################################## GRAFICADO DE PESOS\n
_= plt.hist({0}weights0)\n
_= plt.xlabel('Pesos primera capa oculta')\n
plt.show()\n
_= plt.hist({0}weights1)\n
_= plt.xlabel('Pesos segunda capa oculta')\n
plt.show()\n
_= plt.hist({0}weights2)\n
_= plt.xlabel('Pesos tercera capa oculta')\n
plt.show()\n
_= plt.hist({0}weights3)\n
_= plt.xlabel('Pesos cuarta capa oculta')\n
plt.show()\n
_= plt.hist({0}weights4)\n
_= plt.xlabel('Pesos quinta capa oculta')\n
plt.show()\n
_= plt.hist({0}weights5)\n
_= plt.xlabel('Pesos capa de salida')\n
plt.show()\n
\n
########################################## GRAFICADO DE GRADIENTES MEDIOS\n
_ = plt.figure(figsize=(5,5))\n
_ = plt.ylabel('Valor Promedio gradiente a capa anterior')\n
_ = plt.xlabel('Neuronas en la primera capa oculta')\n
plt.plot(np.mean({0}grafico0.T,axis=0));\n
_ = plt.figure(figsize=(5,5))\n
_ = plt.ylabel('Valor Promedio gradiente a capa anterior')\n
_ = plt.xlabel('Neuronas en la segunda capa oculta')\n
plt.plot(np.mean({0}grafico1.T,axis=0));\n
_ = plt.figure(figsize=(5,5))\n
_ = plt.ylabel('Valor Promedio gradiente a capa anterior')\n
_ = plt.xlabel('Neuronas en la tercera capa oculta')\n
plt.plot(np.mean({0}grafico2.T,axis=0));\n
_ = plt.figure(figsize=(5,5))\n
_ = plt.ylabel('Valor Promedio gradiente a capa anterior')\n
_ = plt.xlabel('Neuronas en la cuarta capa oculta')\n
plt.plot(np.mean({0}grafico3.T,axis=0));\n
_ = plt.figure(figsize=(5,5))\n
_ = plt.ylabel('Valor Promedio gradiente a capa anterior')\n
_ = plt.xlabel('Neuronas en la quinta capa oculta')\n
plt.plot(np.mean({0}grafico4.T,axis=0));\n
_ = plt.figure(figsize=(5,5))\n
_ = plt.ylabel('Valor Promedio gradiente a capa anterior')\n
_ = plt.xlabel('Neuronas en la capa de salidas')\n
plt.plot(np.mean({0}grafico5.T,axis=0));\n
\n
########################################## GRAFICADO DE GRADIENTES\n
_ = plt.figure(figsize=(15,5))\n
_ = plt.xlabel('Neuronas en la capa de entrada')\n
_ = plt.ylabel('Neuronas en la primera capa oculta')\n
plt.imshow({0}grafico0, interpolation='nearest', cmap=cm.Greys_r, extent=[0,1275,0,256])\n
_ = plt.figure(figsize=(5,5))\n
_ = plt.xlabel('Neuronas en la primera capa oculta')\n
_ = plt.ylabel('Neuronas en la segunda capa oculta')\n
plt.imshow({0}grafico1, interpolation='nearest', cmap=cm.Greys_r, extent=[0,256,0,256])\n
_ = plt.figure(figsize=(5,5))\n
_ = plt.xlabel('Neuronas en la segunda capa oculta')\n
_ = plt.ylabel('Neuronas en la tercera capa oculta')\n
plt.imshow({0}grafico2, interpolation='nearest', cmap=cm.Greys_r, extent=[0,256,0,256])\n
_ = plt.figure(figsize=(5,5))\n
_ = plt.xlabel('Neuronas en la tercera capa oculta')\n
_ = plt.ylabel('Neuronas en la cuarta capa oculta')\n
plt.imshow({0}grafico3, interpolation='nearest', cmap=cm.Greys_r, extent=[0,256,0,256])\n
_ = plt.figure(figsize=(5,5))\n
_ = plt.xlabel('Neuronas en la tercera capa oculta')\n
_ = plt.ylabel('Neuronas en la cuarta capa oculta')\n
plt.imshow({0}grafico4, interpolation='nearest', cmap=cm.Greys_r, extent=[0,256,0,256])\n
_ = plt.figure(figsize=(5,5))\n
_ = plt.xlabel('Neuronas en la cuarta capa oculta')\n
_ = plt.ylabel('Neuronas en la capa de salida')\n
plt.imshow({0}grafico5, interpolation='nearest', cmap=cm.Greys_r, extent=[0,256,0,1],aspect='auto')\n
\n
"

for i in lista:
    print(codigo.format(i))
    print("\n\n\n\n")

# %%
lista = ['{0}','B1_','B2_','C1_','C2_','D1_','D2_','E1a_','E2a_','E1b_','E2b_','F1_','F2_','G1_','G2_','F1_','F2_','H1_','H2_']

codigo = "########################################## MODELO DE LA RED\n{0}model = Sequential()\n{0}model.add(Dense(256, input_dim=X_train_scaled.shape[1], kernel_initializer='uniform',activation='sigmoid'))\n{0}model.add(Dense(256, kernel_initializer='uniform',activation='sigmoid'))\n{0}model.add(Dense(256,  kernel_initializer='uniform',activation='sigmoid'))\n{0}model.add(Dense(256, kernel_initializer='uniform',activation='sigmoid'))\n{0}model.add(Dense(256, kernel_initializer='uniform',activation='sigmoid'))\n{0}model.add(Dense(1, kernel_initializer='uniform',activation='linear'))\n{0}sgd = SGD(lr=0.01)\n{0}model.compile(optimizer={0}sgd,loss='mean_squared_error')\n\n########################################## CALCULO DE LOS GRADIENTES\n{0}loss = K.losses.mean_squared_error({0}model.output,y_train)\n{0}listOfVariableTensors = {0}model.trainable_weights\n{0}gradients = k.gradients({0}loss, {0}listOfVariableTensors)\n\n{0}sess = k.get_session()\n\n{0}evaluated_gradients = {0}sess.run({0}gradients,feed_dict={{ {0}model.input:X_train_scaled.values}})\n{0}evaluated_gradients = [gradient/len(y_train) for gradient in {0}evaluated_gradients]\n\n########################################## OBTENCION DE PESOS \n{0}weights0, {0}biases0 = {0}model.layers[0].get_weights()\n{0}weights1, {0}biases1 = {0}model.layers[1].get_weights()\n{0}weights2, {0}biases2 = {0}model.layers[2].get_weights()\n{0}weights3, {0}biases3 = {0}model.layers[3].get_weights()\n{0}weights4, {0}biases4 = {0}model.layers[4].get_weights()\n{0}weights5, {0}biases5 = {0}model.layers[5].get_weights()\n\n########################################## OBTENCION DE GRADIENTES\n{0}grafico0={0}evaluated_gradients[0]\n{0}grafico1={0}evaluated_gradients[2]\n{0}grafico2={0}evaluated_gradients[4]\n{0}grafico3={0}evaluated_gradients[6]\n{0}grafico4={0}evaluated_gradients[8]\n{0}grafico5={0}evaluated_gradients[10]\n\n########################################## GRAFICADO DE PESOS\n_= plt.hist({0}weights0)\n_= plt.xlabel('Pesos primera capa oculta')\nplt.show()\n_= plt.hist({0}weights1)\n_= plt.xlabel('Pesos segunda capa oculta')\nplt.show()\n_= plt.hist({0}weights2)\n_= plt.xlabel('Pesos tercera capa oculta')\nplt.show()\n_= plt.hist({0}weights3)\n_= plt.xlabel('Pesos cuarta capa oculta')\nplt.show()\n_= plt.hist({0}weights4)\n_= plt.xlabel('Pesos quinta capa oculta')\nplt.show()\n_= plt.hist({0}weights5)\n_= plt.xlabel('Pesos capa de salida')\nplt.show()\n\n########################################## GRAFICADO DE GRADIENTES MEDIOS\n_ = plt.figure(figsize=(5,5))\n_ = plt.ylabel('Valor Promedio gradiente a capa anterior')\n_ = plt.xlabel('Neuronas en la primera capa oculta')\nplt.plot(np.mean({0}grafico0,axis=0));\n_ = plt.figure(figsize=(5,5))\n_ = plt.ylabel('Valor Promedio gradiente a capa anterior')\n_ = plt.xlabel('Neuronas en la segunda capa oculta')\nplt.plot(np.mean({0}grafico1,axis=0));\n_ = plt.figure(figsize=(5,5))\n_ = plt.ylabel('Valor Promedio gradiente a capa anterior')\n_ = plt.xlabel('Neuronas en la tercera capa oculta')\nplt.plot(np.mean({0}grafico2,axis=0));\n_ = plt.figure(figsize=(5,5))\n_ = plt.ylabel('Valor Promedio gradiente a capa anterior')\n_ = plt.xlabel('Neuronas en la cuarta capa oculta')\nplt.plot(np.mean({0}grafico3,axis=0));\n_ = plt.figure(figsize=(5,5))\n_ = plt.ylabel('Valor Promedio gradiente a capa anterior')\n_ = plt.xlabel('Neuronas en la quinta capa oculta')\nplt.plot(np.mean({0}grafico4,axis=0));\n_ = plt.figure(figsize=(5,5))\n_ = plt.ylabel('Valor Promedio gradiente a capa anterior')\n_ = plt.xlabel('Neuronas en la capa de salidas')\nplt.plot(np.mean({0}grafico5,axis=0));\n\n########################################## GRAFICADO DE GRADIENTES\n_ = plt.figure(figsize=(15,5))\n_ = plt.xlabel('Neuronas en la capa de entrada')\n_ = plt.ylabel('Neuronas en la primera capa oculta')\nplt.imshow({0}grafico0, interpolation='nearest', cmap=cm.Greys_r, extent=[0,1275,0,256])\n_ = plt.figure(figsize=(5,5))\n_ = plt.xlabel('Neuronas en la primera capa oculta')\n_ = plt.ylabel('Neuronas en la segunda capa oculta')\nplt.imshow({0}grafico1, interpolation='nearest', cmap=cm.Greys_r, extent=[0,256,0,256])\n_ = plt.figure(figsize=(5,5))\n_ = plt.xlabel('Neuronas en la segunda capa oculta')\n_ = plt.ylabel('Neuronas en la tercera capa oculta')\nplt.imshow({0}grafico2, interpolation='nearest', cmap=cm.Greys_r, extent=[0,256,0,256])\n_ = plt.figure(figsize=(5,5))\n_ = plt.xlabel('Neuronas en la tercera capa oculta')\n_ = plt.ylabel('Neuronas en la cuarta capa oculta')\nplt.imshow({0}grafico3, interpolation='nearest', cmap=cm.Greys_r, extent=[0,256,0,256])\n_ = plt.figure(figsize=(5,5))\n_ = plt.xlabel('Neuronas en la tercera capa oculta')\n_ = plt.ylabel('Neuronas en la cuarta capa oculta')\nplt.imshow({0}grafico4, interpolation='nearest', cmap=cm.Greys_r, extent=[0,256,0,256])\n_ = plt.figure(figsize=(5,5))\n_ = plt.xlabel('Neuronas en la cuarta capa oculta')\n_ = plt.ylabel('Neuronas en la capa de salida')\nplt.imshow({0}grafico5, interpolation='nearest', cmap=cm.Greys_r, extent=[0,256,0,1],aspect='auto')\n\n"

for i in lista:
    print(codigo.format(i))
    print("\n\n\n\n")
# Out:
# ########################################## MODELO DE LA RED
# {0}model = Sequential()
# {0}model.add(Dense(256, input_dim=X_train_scaled.shape[1], kernel_initializer='uniform',activation='sigmoid'))
# {0}model.add(Dense(256, kernel_initializer='uniform',activation='sigmoid'))
# {0}model.add(Dense(256,  kernel_initializer='uniform',activation='sigmoid'))
# {0}model.add(Dense(256, kernel_initializer='uniform',activation='sigmoid'))
# {0}model.add(Dense(256, kernel_initializer='uniform',activation='sigmoid'))
# {0}model.add(Dense(1, kernel_initializer='uniform',activation='linear'))
# {0}sgd = SGD(lr=0.01)
# {0}model.compile(optimizer={0}sgd,loss='mean_squared_error')
#
# ########################################## CALCULO DE LOS GRADIENTES
# {0}loss = K.losses.mean_squared_error({0}model.output,y_train)
# {0}listOfVariableTensors = {0}model.trainable_weights
# {0}gradients = k.gradients({0}loss, {0}listOfVariableTensors)
#
# {0}sess = k.get_session()
#
# ...
